# %%
import numpy as np, matplotlib.pyplot as plt

ms = np.loadtxt('Flux_cal_JHK_2M2255-3118.txt')

wave = ms[:, 0] * 1e-4 # A to um
flux = ms[:, 1] * 1e-11 # erg/cm^2/s/A to W/m^2/um
unc = ms[:, 2] * 1e-11 # erg/cm^2/s/A to W/m^2/um

# %%
plt.plot(wave, flux)
print(np.mean(flux))
# Out:
# 1.1546970627924207e-24

# %%
out = 'Flux_cal_JHK_2M2255-3118_species_units.txt'
np.savetxt(out, [wave, flux, unc])
